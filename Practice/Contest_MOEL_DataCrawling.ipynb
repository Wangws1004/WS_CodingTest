# %%
# pip install xmltodict

# %%
import requests
import xmltodict
import pandas as pd

# %%
# API Key와 URL 설정
api_key = 'fed94136a305f851b96569cf'
url = 'https://www.youthcenter.go.kr/opi/youthPlcyList.do'

# %%
# 요청 파라미터 설정 (보다 일반적으로 수정)
params = {
    'openApiVlak': api_key,
    'pageIndex': 1,
    'display': 10,
    'query': '',  # 빈 값으로 설정하여 모든 정책 검색
    'bizTycdSel': '',  # 빈 값으로 설정하여 모든 비즈니스 유형 검색
    'srchPolyBizSecd': '',  # 빈 값으로 설정하여 모든 정책 섹션 검색
    'keyword': ''  # 빈 값으로 설정하여 모든 키워드 검색
}

# API 요청
response = requests.get(url, params=params)

# XML 응답을 딕셔너리로 변환
data_dict = xmltodict.parse(response.content)

# 응답 데이터 구조 확인
import json
print(json.dumps(data_dict, indent=4, ensure_ascii=False))

# 데이터프레임으로 변환
try:
    data_list = data_dict['youthPolicyList']['youthPolicy']
    df = pd.DataFrame(data_list)
    print(df)
    # CSV 파일로 저장
    df.to_csv('youth_policy_data.csv', index=False)
    print('데이터가 youth_policy_data.csv 파일로 저장되었습니다.')
except KeyError as e:
    print(f"응답 데이터에 키 {e}가(이) 없습니다. 응답 데이터를 확인하세요.")
# Out:
# {
#     "youthPolicyList": {
#         "pageIndex": "1",
#         "totalCnt": "2037",
#         "youthPolicy": [
#             {
#                 "rnum": "1",
#                 "bizId": "R2024070424704",
#                 "polyBizSecd": "003002005004",
#                 "polyBizTy": "지자체",
#                 "polyBizSjnm": "청년 로컬디저트 메뉴개발 컨설팅",
#                 "polyItcnCn": "청년창업가의 창업 경쟁력을 높이기 위해 로컬을 활용한 디저트 메뉴개발을 지원",
#                 "sporCn": "□ 로컬 디저트 메뉴 개발(시크니처 메뉴)지원\n- 메뉴개발컨설팅, 실습공간·식재료지원, 시식회, 정책연계 등\n□ 교육기간 : 2024. 7월 ~ 10월(4개월)\n□ 교육장소 : 청년 로컬크리에이터 라운지(북구 행복어울림센터 1층)\n※ 북구 행복어울림센터 : 북구 용봉로 105(용봉동), 전남대 정문에서 북구청 사이\n□ 지원분야\n❍ 로컬일반 : 로컬재료활용, 지역문화·디자인 접목 등\n❍ 북구특성화 : 북구도시브랜드(부끄부부)활용\n□ 후속지원\n❍ 시제품 매장 판매실습\n❍ 창업 지원정책 연계",
#                 "sporScvl": "4개팀 (개인 또는 팀)",
#                 "bizPrdCn": "null",
#                 "prdRpttSecd": "002004",
#                 "rqutPrdCn": "2024-06-25~2024-07-07\n2024년 6월 25일(화) ~ 2024년 7월 7일(일) (13일간)",
#                 "ageInfo": "만 19세 ~ 39세",
#                 "majrRqisCn": "-",
#                 "empmSttsCn": "초기창업자(5년이내), 예비창업자",
#                 "splzRlmRqisCn": "-",
#                 "accrRqisCn": "-",
#                 "prcpCn": "북구 관내 사업장 소재 청년 초기창업자(5년이내), 예비창업자",
#                 "aditRscn": "null",
#                 "prcpLmttTrgtCn": "null",
#                 "rqutProcCn": "접수방법 : 청년센터 홈페이지 온라인신청<공지사항>",
#                 "pstnPaprCn": "참여신청서, 사업계획서, 사업자등록증, 창업공간 사진 등",
#                 "jdgnPresCn": "최종선정결과 발표 : 7월12일(금)",
#                 "rqutUrla": "https://bukgu.gwangju.kr/youth/",
#                 "rfcSiteUrla1": "null",
#                 "rfcSiteUrla2": "null",
#                 "mngtMson": "북구 청년미래정책관",
#                 "mngtMrofCherCn": "null",
#                 "cherCtpcCn": "null",
#                 "cnsgNmor": "북구청년센터",
#                 "tintCherCn": "null",
#                 "tintCherCtpcCn": "null",
#                 "etct": "□ 문의처\n❍ 북구청년센터 T.410-8262~3 / 카카오톡 채널 @광주북구청년센터 \n❍ 북구청년미래정책관(청년센터) T.410-8240",
#                 "polyRlmCd": "023010"
#             },
#             {
#                 "rnum": "2",
#                 "bizId": "R2024070424688",
#                 "polyBizSecd": "003002005",
#                 "polyBizTy": "지자체",
#                 "polyBizSjnm": "청년 (예비)창업가 거주시설 지원",
#                 "polyItcnCn": "청년 예비창업가 및 초기창업자에게 사무와 주거가 한 곳에서 가능한 임대 주택을 저렴하게 제공하여 주거 안정 및 창업기업 성장을 지원",
#                 "sporCn": "□ 위치 : 북구 저불로 73번길 22-3(용봉동)\n□ 지원공간\n❍ 사무실 겸 주택 7호(2인실 2호, 3인실 5호), 세대당 전용면적 53~61㎡\n❍ 부대시설 : 공용시설 2호(회의실, 휴게실), 옥상텃밭\n□ 임대료 : 보증금 420만원 내외, 월 임대료 35만원 내외\n□ 입주기간 : 2년(심사를 거쳐 1회 연장 가능, 최장 4년)",
#                 "sporScvl": "null",
#                 "bizPrdCn": "null",
#                 "prdRpttSecd": "002001",
#                 "rqutPrdCn": "공실 발생시 모집",
#                 "ageInfo": "만 0세 ~ 39세",
#                 "majrRqisCn": "-",
#                 "empmSttsCn": "초기창업자(3년 이내) 또는 예비창업자",
#                 "splzRlmRqisCn": "-",
#                 "accrRqisCn": "-",
#                 "prcpCn": "□ 거주지 : 광주 거주 \n□ 연령 : 39세 이하 \n□ 대상 : 초기창업자(3년 이내) 또는 예비창업자\n□ 주거 : 무주택세대구성원\n□ 소득 : 전년도 도시근로자 가구당 월평균소득의 70%이하",
#                 "aditRscn": "null",
#                 "prcpLmttTrgtCn": "null",
#                 "rqutProcCn": "공실 발생시 I-PLEX광주 홈페이지(www.iplexgj.com), (재)광주테크노파크 홈페이지 (www.gjtp.or.kr)에 모집 공고",
#                 "pstnPaprCn": "입주신청서 및 사업계획서 등",
#                 "jdgnPresCn": "null",
#                 "rqutUrla": "null",
#                 "rfcSiteUrla1": "https://www.iplexgj.com",
#                 "rfcSiteUrla2": "https://www.gjtp.or.kr",
#                 "mngtMson": "광주광역시 창업진흥과",
#                 "mngtMrofCherCn": "null",
#                 "cherCtpcCn": "null",
#                 "cnsgNmor": "(재)광주테크노파크",
#                 "tintCherCn": "null",
#                 "tintCherCtpcCn": "null",
#                 "etct": "□ 문의처\n❍ (재)광주테크노파크 기업지원단 I-PLEX센터(전담기관) T. 062-239-9613~5\n❍ I-PLEX광주 홈페이지 www.iplexgj.com, (재)광주테크노파크 홈페이지 www.gjtp.or.kr",
#                 "polyRlmCd": "023010"
#             },
#             {
#                 "rnum": "3",
#                 "bizId": "R2024070424687",
#                 "polyBizSecd": "003002012012",
#                 "polyBizTy": "지자체",
#                 "polyBizSjnm": "2024년 하반기 순창군 행정인턴사업 참여자 모집 안내",
#                 "polyItcnCn": "대학생 및 청년에게 다양한 사회경험 등 진로탐색의 기회를 제공하기 위해 「2024년 하반기 순창군 행정인턴 사업」참여자를 아래와 같이 모집",
#                 "sporCn": "군청 및 사업소, 읍․면 행정복지센터에서 직무경험을 할 수 있도록 하고, 1일 78,880원/8시간(시급 9,860원) 지급",
#                 "sporScvl": "24명",
#                 "bizPrdCn": "-",
#                 "prdRpttSecd": "002004",
#                 "rqutPrdCn": "2024-07-03~2024-07-11\n2024-07-03(수) ~ 2024-07-11(목)",
#                 "ageInfo": "만 19세 ~ 34세",
#                 "majrRqisCn": "-",
#                 "empmSttsCn": "-",
#                 "splzRlmRqisCn": "-",
#                 "accrRqisCn": "-",
#                 "prcpCn": "□ 공통 : 공고일 현재 순창군에 주민등록이 되어 있는 대학생(휴학생) 또는「청년기본법」상 19세 이상 34세 이하 청년 (1990.6.28.~ 2005.6.28.출생자)\n□ 우선선발 : 기초생활수급자, 차상위계층, 한부모가족보호대상자/원거리근무지",
#                 "aditRscn": "-",
#                 "prcpLmttTrgtCn": "행정인턴 기참여자",
#                 "rqutProcCn": "방문 또는 우편, E-mail 접수(접수장소 : 전북 순창군 순창읍 경천로 33, 순창군청 1층 행정과 인재평생교육팀)",
#                 "pstnPaprCn": "□ (공통서류) 신청서, 개인정보제공 동의서, 주민등록초본 각 1부.\n□ (해당자) 기초생활수급자증명서·차상위계층 증명서·한부모가족증명서",
#                 "jdgnPresCn": "□ 일  자 : 2024. 7. 16.(화)\n□ 방  법 : 홈페이지 공고 및 개별(문자) 통보",
#                 "rqutUrla": "-",
#                 "rfcSiteUrla1": "-",
#                 "rfcSiteUrla2": "-",
#                 "mngtMson": "순창군",
#                 "mngtMrofCherCn": "-",
#                 "cherCtpcCn": "063-650-1236",
#                 "cnsgNmor": "순창군",
#                 "tintCherCn": "-",
#                 "tintCherCtpcCn": "063-650-1236",
#                 "etct": "-",
#                 "polyRlmCd": "023010"
#             },
#             {
#                 "rnum": "4",
#                 "bizId": "R2024070424686",
#                 "polyBizSecd": "003002005",
#                 "polyBizTy": "지자체",
#                 "polyBizSjnm": "2024년 광주광역시 청년창업 특례보증",
#                 "polyItcnCn": "아이디어와 기술력은 있으나 자금과 담보력이 부족한 지역 내 청년창업가를 대상으로 최대 5천만원 이내의 특례보증을 지원",
#                 "sporCn": "□ 대출한도 : 업체당 최대 50백만원 이내\n□ 보증기간 : 1년 / 5년\n□ 상환방식 : 1년 일시상환 / 1년 거치 4년 원금균등분할상환(매월)\n□ 보증료율 : 연 0.5%\n□ 취급금융기관 : 광주은행, NH농협은행, KB국민은행, 신한은행, 우리은행, 하나은행, IBK기업은행\n□ 특이사항 : 광주광역시에서 1년차 3% 이차보전",
#                 "sporScvl": "200억원",
#                 "bizPrdCn": "null",
#                 "prdRpttSecd": "002004",
#                 "rqutPrdCn": "2024-03-11~2024-12-31\n2024. 3. 11. ~ 예산 소진 시까지",
#                 "ageInfo": "만 0세 ~ 39세",
#                 "majrRqisCn": "-",
#                 "empmSttsCn": "사업자등록 후 가동(영업) 중인 업력 7년 이하의 소기업·소상공인",
#                 "splzRlmRqisCn": "-",
#                 "accrRqisCn": "-",
#                 "prcpCn": "광주광역시 소재 사업장으로 현재 사업자등록 후 가동(영업)중인 만 39세 이하, 개인 신용평점 355점 이상, 업력 7년 이하인 소기업·소상공인",
#                 "aditRscn": "null",
#                 "prcpLmttTrgtCn": "- 대표자 개인신용평점 354점 이하인 기업\n- 재단 제규정상 재보증제한 기업\n- 만 40세 이상\n- 업력 8년 이상",
#                 "rqutProcCn": "광주신용보증재단 신청",
#                 "pstnPaprCn": "null",
#                 "jdgnPresCn": "① 신용보증상담, 관련 서류 접수\n② 신용상태 조사 및 심사(사업장 현장조사)\n③ 신용보증 결정 여부 통보(→ 신청기업)\n④ 여신심사 및 대출(보증서 담보 대출금 지급)",
#                 "rqutUrla": "https://www.gjsinbo.or.kr/?d=guarantee_product3_01",
#                 "rfcSiteUrla1": "https://www.gjsinbo.or.kr/?d=guarantee_product3_01",
#                 "rfcSiteUrla2": "null",
#                 "mngtMson": "광주광역시 창업진흥과",
#                 "mngtMrofCherCn": "null",
#                 "cherCtpcCn": "null",
#                 "cnsgNmor": "광주신용보증재단",
#                 "tintCherCn": "null",
#                 "tintCherCtpcCn": "null",
#                 "etct": "문의처\n- 광주신용보증재단(062-950-0000, www.gjsinbo.or.kr)",
#                 "polyRlmCd": "023010"
#             },
#             {
#                 "rnum": "5",
#                 "bizId": "R2024070424703",
#                 "polyBizSecd": "003002005003",
#                 "polyBizTy": "지자체",
#                 "polyBizSjnm": "구직청년 면접용 정장 대여",
#                 "polyItcnCn": "면접용 정장 무료 대여",
#                 "sporCn": "□ 면접용 정장 무료 대여\n❍ 대여항목 : 재킷, 셔츠, 바지, 넥타이 블라우스, 치마 등\n❍ 전문 디자이너가 코디, 기장 수선 등 맞춤형 서비스 제공\n□ 제공업체 : 다나베 비스포크\n❍ 화요일은 매장 운영하지 않음\n□ 대여 기간 : 3박 4일 / 1회\n□ 대여 횟수 : 연 3회",
#                 "sporScvl": "-",
#                 "bizPrdCn": "2024.01.01.~2024.12.31.",
#                 "prdRpttSecd": "002004",
#                 "rqutPrdCn": "2024-07-04~2024-12-20\n12월 20일까지 서비스 제공",
#                 "ageInfo": "만 19세 ~ 45세",
#                 "majrRqisCn": "-",
#                 "empmSttsCn": "청년 구직자",
#                 "splzRlmRqisCn": "-",
#                 "accrRqisCn": "-",
#                 "prcpCn": "광주광역시 남구에 주소를 둔 19~45세 청년 구직자",
#                 "aditRscn": "-",
#                 "prcpLmttTrgtCn": "-",
#                 "rqutProcCn": "□ 서비스 이용 전 남구청 일자리정책과 방문 또는 담당자 이메일(hee1187@korea.kr)로 신청서 등 증빙서류 제출\n□ 예약 날짜에 매장(다나베 비스포크) 방문",
#                 "pstnPaprCn": "-",
#                 "jdgnPresCn": "-",
#                 "rqutUrla": "-",
#                 "rfcSiteUrla1": "-",
#                 "rfcSiteUrla2": "-",
#                 "mngtMson": "광주광역시 남구청 일자리정책과",
#                 "mngtMrofCherCn": "-",
#                 "cherCtpcCn": "-",
#                 "cnsgNmor": "-",
#                 "tintCherCn": "-",
#                 "tintCherCtpcCn": "-",
#                 "etct": "문의처 : 남구청 일자리정책과(062-607-2681)",
#                 "polyRlmCd": "023010"
#             },
#             {
#                 "rnum": "6",
#                 "bizId": "R2024070424684",
#                 "polyBizSecd": "003002005",
#                 "polyBizTy": "지자체",
#                 "polyBizSjnm": "광주 청년 면접 정장 대여 서비스",
#                 "polyItcnCn": "광주 지역 청년들이 취업 대비에 필요한 면접 정장대여, 이력서 사진 촬영 서비스를 무료로 제공",
#                 "sporCn": "□ 청년구직자 면접 정장 무료 대여(1인당 연간 5회 한도 / 대여기간 최대 3박 4일 *휴일 미포함)\n❍ 재킷, 바지, 스커트, 셔츠, 블라우스, 넥타이, 구두 등 정장일체(여름용 정장, 여성 바지 구비)\n□ 이력서 사진 무료 촬영 서비스(1인당 연간 1회 한도 / 격주 수요일 오후 ＊사전 문의·예약 필수)\n❍ 1:1 매칭 포토샵 수정, 현장 사진 인화 제공 등",
#                 "sporScvl": "null",
#                 "bizPrdCn": "null",
#                 "prdRpttSecd": "002001",
#                 "rqutPrdCn": "홈페이지 사전 예약 신청 후 이용",
#                 "ageInfo": "만 19세 ~ 39세",
#                 "majrRqisCn": "-",
#                 "empmSttsCn": "청년 구직자",
#                 "splzRlmRqisCn": "-",
#                 "accrRqisCn": "-",
#                 "prcpCn": "null",
#                 "aditRscn": "null",
#                 "prcpLmttTrgtCn": "null",
#                 "rqutProcCn": "토닥토닥 청년일자리(JOB)카페 홈페이지 접속 후 사전 예약 신청\n① 홈페이지 회원가입 및 서비스 이용 예약(신청서 제출)\n- 토닥토닥 청년일자리(JOB)카페(www.todaktodakjob.com)\n② 구비서류 제출 \n- 주민등록등본, 신분증 사본, 면접증빙 서류 등\n③ 면접정장 수령 또는 이력서 사진 촬영\n- 토닥토닥 청년일자리(JOB)카페(광주 서구 상무중앙로 34)\n④ 면접정장 반납 또는 촬영일 현장 방문\n- 예약 승인 후 직접 방문 이용",
#                 "pstnPaprCn": "null",
#                 "jdgnPresCn": "null",
#                 "rqutUrla": "https://www.todaktodakjob.com",
#                 "rfcSiteUrla1": "null",
#                 "rfcSiteUrla2": "null",
#                 "mngtMson": "광주광역시 청년정책관",
#                 "mngtMrofCherCn": "null",
#                 "cherCtpcCn": "062-613-2174",
#                 "cnsgNmor": "토닥토닥 청년일자리(JOB)카페",
#                 "tintCherCn": "null",
#                 "tintCherCtpcCn": "062-372-5990~3",
#                 "etct": "문의처\n❍ 카카오톡 플러스친구 : 토닥토닥청년일자리카페\n❍ 토닥토닥 청년일자리(job)카페 홈페이지 : https://www.todaktodakjob.com \n❍ 토닥토닥 청년일자리(JOB)카페 T. 062-372-5990~3",
#                 "polyRlmCd": "023010"
#             },
#             {
#                 "rnum": "7",
#                 "bizId": "R2024070424683",
#                 "polyBizSecd": "003002006",
#                 "polyBizTy": "지자체",
#                 "polyBizSjnm": "청년성장프로젝트",
#                 "polyItcnCn": "미취업 청년의 구직단념을 사전 예방하고, 중소/중견기업 신입직원 직장적응 지원",
#                 "sporCn": "(청년카페운영) 일상 및 구직의욕 유지를 지원하기 위한 맞춤형 프로그램 - (직장적응지원) 기업관리자, 신입직원 대상 청년친화 조직문화 교육\n❚교육내용 - (청년카페운영) 대상별, 기관별 맞춤형 구직단념 예방 프로그램(20시간) \n*초기상담, 경력재설계, 취업역량강화, 네트워킹지원 등 - (직장적응지원) 청년친화 조직문화 조성(10시간) *협업 커뮤니케이션 스킬, 비즈니스 매너, 갑질 예방 등 \n❚교육장소 : 7개소 거점 운영 - (청년카페운영) 대전일자리지원센터(중구선화동), 대전지식산업센터(동구대동), D-유니콘라운지(유성구도룡동), 청춘나들목(대전역), 청춘너나들이(서구 탄방동), 동구동락(동구 자양동) - (직장적응지원) 대전상공회의소(서구둔산동), D-유니콘라운지(유성구도룡동)",
#                 "sporScvl": "-",
#                 "bizPrdCn": "-",
#                 "prdRpttSecd": "002001",
#                 "rqutPrdCn": "-",
#                 "ageInfo": "제한없음",
#                 "majrRqisCn": "-",
#                 "empmSttsCn": "-",
#                 "splzRlmRqisCn": "-",
#                 "accrRqisCn": "-",
#                 "prcpCn": "-",
#                 "aditRscn": "-",
#                 "prcpLmttTrgtCn": "- (청년카페운영) 만 15세~39세 미취업 청년 \n- (직장적응지원) 지역 중소·중견기업 관리자(CEO, 인사담당자 등), 1년 이내 신입직원",
#                 "rqutProcCn": "고용24 ( www.work24.go.kr) 또는 대전청년포털 ＞ 청년활동 ＞ 청년성장프로젝트 신청 \n❚문의 - (청년카페운영) 대전일자리지원센터(☏ 042-719-8335) 대전청년내일센터(☏ 070-7778-1149) 대전동구동락(☏ 070-4252-0909) - (직장적응지원) 대전상공회의소(☏ 042-480-3044)",
#                 "pstnPaprCn": "-",
#                 "jdgnPresCn": "-",
#                 "rqutUrla": "https://youth-up.kr/growth",
#                 "rfcSiteUrla1": "https://www.daejeonyouthportal.kr/content/CT_000000000371/cntPage.do?commonMenuNo=344_406",
#                 "rfcSiteUrla2": "-",
#                 "mngtMson": "-",
#                 "mngtMrofCherCn": "-",
#                 "cherCtpcCn": "-",
#                 "cnsgNmor": "대전일자리지원센터(☏ 042-719-8335), 대전청년내일센터(☏ 070-7778-1149), 대전동구동락(☏ 070-4252-0909), 대전상공회의소(☏ 042-480-3044)",
#                 "tintCherCn": "-",
#                 "tintCherCtpcCn": "-",
#                 "etct": "-",
#                 "polyRlmCd": "023010"
#             },
#             {
#                 "rnum": "8",
#                 "bizId": "R2024070324667",
#                 "polyBizSecd": "003002001006",
#                 "polyBizTy": "지자체",
#                 "polyBizSjnm": "하반기 동대문구 동행일자리 사업 참여자 모집",
#                 "polyItcnCn": "취업취약계층을 대상으로 경제활동 기회 제공 및 생계지원 사업",
#                 "sporCn": "경제활동 기회 제공 및 생계지원 사업",
#                 "sporScvl": "37명(14개 사업)",
#                 "bizPrdCn": "2024. 8. 1. ~ 12. 20.",
#                 "prdRpttSecd": "002004",
#                 "rqutPrdCn": "2024-06-27~2024-07-03\n- 20024. 6. 27.(목) ~ 7. 5.(금) 09:00~18:00   [토・일요일 및 대체공휴일 제외]  \n- 청년사업: 사업개시일 기준 만 18세 이상~만 39세 이하(1985.1.1. 이후 출생)인 자만 지원 가능",
#                 "ageInfo": "만 18세 ~ 39세",
#                 "majrRqisCn": "제한없음",
#                 "empmSttsCn": "실업자 또는 정기적인 소득이 없는 취업 취약계층",
#                 "splzRlmRqisCn": "제한없음",
#                 "accrRqisCn": "제한없음",
#                 "prcpCn": "사업개시일 현재 18세 이상 근로능력이 있는 동대문구민",
#                 "aditRscn": "null",
#                 "prcpLmttTrgtCn": "null",
#                 "rqutProcCn": "신청인 본인 주민등록지 동 주민센터(신분증 지참 방문접수)",
#                 "pstnPaprCn": "null",
#                 "jdgnPresCn": "선발발표 : 2024. 7. 29. (월) 예정  ※ 선발자에 한해 사업부서 개별 통보",
#                 "rqutUrla": "null",
#                 "rfcSiteUrla1": "https://www.ddm.go.kr/www/selectBbsNttView.do?key=198&bbsNo=38&nttNo=151650",
#                 "rfcSiteUrla2": "null",
#                 "mngtMson": "동대문구 일자리청년과",
#                 "mngtMrofCherCn": "null",
#                 "cherCtpcCn": "02-2127-4973",
#                 "cnsgNmor": "주관기관 동일",
#                 "tintCherCn": "null",
#                 "tintCherCtpcCn": "null",
#                 "etct": "동대문구 일자리청년과 ☎02-2127-4973(동행일자리사업)   \n\n- 기타 사업에 관한 보다 자세한 사항은 첨부된 각 사업별 공고문을 반드시 확인하여 주시기 바랍니다.",
#                 "polyRlmCd": "023010"
#             },
#             {
#                 "rnum": "9",
#                 "bizId": "R2024070324665",
#                 "polyBizSecd": "003002001002",
#                 "polyBizTy": "지자체",
#                 "polyBizSjnm": "중구일자리플러스센터",
#                 "polyItcnCn": "취업 희망 주민과 구인업체를 서로 연계하여, 기업에 맞는 맞춤형 인재를 알선하고 구민에게는 양질의 일자리를 제공해 주는 창구 사업",
#                 "sporCn": "취업절차 : 지원서제출 ⇒ 지원서관리 ⇒ 기업연계 ⇒ 민간일자리 직접 연계",
#                 "sporScvl": "null",
#                 "bizPrdCn": "null",
#                 "prdRpttSecd": "002001",
#                 "rqutPrdCn": "상시모집",
#                 "ageInfo": "제한없음",
#                 "majrRqisCn": "제한없음",
#                 "empmSttsCn": "제한없음",
#                 "splzRlmRqisCn": "제한없음",
#                 "accrRqisCn": "제한없음",
#                 "prcpCn": "null",
#                 "aditRscn": "null",
#                 "prcpLmttTrgtCn": "null",
#                 "rqutProcCn": "- 방문접수\n- 온라인 접수\n(홈페이지 바로가기 : https://job.seoul.go.kr/junggu)",
#                 "pstnPaprCn": "null",
#                 "jdgnPresCn": "null",
#                 "rqutUrla": "https://job.seoul.go.kr/junggu",
#                 "rfcSiteUrla1": "https://www.junggu.seoul.kr/content.do?cmsid=14196",
#                 "rfcSiteUrla2": "null",
#                 "mngtMson": "서울시 중구",
#                 "mngtMrofCherCn": "일자리경제과",
#                 "cherCtpcCn": "02-3396-5682",
#                 "cnsgNmor": "주관기관 동일",
#                 "tintCherCn": "null",
#                 "tintCherCtpcCn": "null",
#                 "etct": "null",
#                 "polyRlmCd": "023010"
#             },
#             {
#                 "rnum": "10",
#                 "bizId": "R2024070324663",
#                 "polyBizSecd": "003002001002",
#                 "polyBizTy": "지자체",
#                 "polyBizSjnm": "청년 소상공인을 위한 고민상담소",
#                 "polyItcnCn": "\"행복잇다 사회적협동조합\"에서는 서울시민의 행복감 증진을 위한 심리상담 및 교육  등을 진행하고  \"청년 소상공인을 위한 심리교육\" 프로그램",
#                 "sporCn": "청년 소상공인을 위한 심리교육",
#                 "sporScvl": "-",
#                 "bizPrdCn": "null",
#                 "prdRpttSecd": "002004",
#                 "rqutPrdCn": "2024-06-21~2024-12-31\n* 모집기간 :  2024.6.21.(금) ~ 상시모집",
#                 "ageInfo": "만 19세 ~ 34세",
#                 "majrRqisCn": "제한없음",
#                 "empmSttsCn": "청년 소상공인",
#                 "splzRlmRqisCn": "제한없음",
#                 "accrRqisCn": "제한없음",
#                 "prcpCn": "19세이상 34세이하 청년사장님(사업자등록증 확인)",
#                 "aditRscn": "null",
#                 "prcpLmttTrgtCn": "null",
#                 "rqutProcCn": "* 신청방법 : 서울심리지원 제4권역(중부)센터 홈페이지 및 포스터 QR 신청\n- 첨부파일 필수 확인",
#                 "pstnPaprCn": "null",
#                 "jdgnPresCn": "null",
#                 "rqutUrla": "* 신청방법 : 서울심리지원 제4권역(중부)센터 홈페이지 및 포스터 QR 신청",
#                 "rfcSiteUrla1": "null",
#                 "rfcSiteUrla2": "null",
#                 "mngtMson": "서울시 중구청",
#                 "mngtMrofCherCn": "null",
#                 "cherCtpcCn": "null",
#                 "cnsgNmor": "행복잇다 사회적협동조합",
#                 "tintCherCn": "null",
#                 "tintCherCtpcCn": "null",
#                 "etct": "null",
#                 "polyRlmCd": "023030"
#             }
#         ]
#     }
# }
#   rnum           bizId   polyBizSecd polyBizTy
# 0    1  R2024070424704  003002005004       지자체  \
# 1    2  R2024070424688     003002005       지자체
# 2    3  R2024070424687  003002012012       지자체
# 3    4  R2024070424686     003002005       지자체
# 4    5  R2024070424703  003002005003       지자체
# 5    6  R2024070424684     003002005       지자체
# 6    7  R2024070424683     003002006       지자체
# 7    8  R2024070324667  003002001006       지자체
# 8    9  R2024070324665  003002001002       지자체
# 9   10  R2024070324663  003002001002       지자체
#
#                       polyBizSjnm
# 0               청년 로컬디저트 메뉴개발 컨설팅  \
# 1              청년 (예비)창업가 거주시설 지원
# 2  2024년 하반기 순창군 행정인턴사업 참여자 모집 안내
# 3           2024년 광주광역시 청년창업 특례보증
# 4                  구직청년 면접용 정장 대여
# 5              광주 청년 면접 정장 대여 서비스
# 6                        청년성장프로젝트
# 7        하반기 동대문구 동행일자리 사업 참여자 모집
# 8                      중구일자리플러스센터
# 9               청년 소상공인을 위한 고민상담소
#
#                                           polyItcnCn
# 0         청년창업가의 창업 경쟁력을 높이기 위해 로컬을 활용한 디저트 메뉴개발을 지원  \
# 1  청년 예비창업가 및 초기창업자에게 사무와 주거가 한 곳에서 가능한 임대 주택을 저렴...
# 2  대학생 및 청년에게 다양한 사회경험 등 진로탐색의 기회를 제공하기 위해 「2024년...
# 3  아이디어와 기술력은 있으나 자금과 담보력이 부족한 지역 내 청년창업가를 대상으로 최...
# 4                                       면접용 정장 무료 대여
# 5  광주 지역 청년들이 취업 대비에 필요한 면접 정장대여, 이력서 사진 촬영 서비스를 ...
# 6        미취업 청년의 구직단념을 사전 예방하고, 중소/중견기업 신입직원 직장적응 지원
# 7                  취업취약계층을 대상으로 경제활동 기회 제공 및 생계지원 사업
# 8  취업 희망 주민과 구인업체를 서로 연계하여, 기업에 맞는 맞춤형 인재를 알선하고 구...
# 9  "행복잇다 사회적협동조합"에서는 서울시민의 행복감 증진을 위한 심리상담 및 교육  ...
#
#                                               sporCn       sporScvl
# 0  □ 로컬 디저트 메뉴 개발(시크니처 메뉴)지원\n- 메뉴개발컨설팅, 실습공간·식재료...  4개팀 (개인 또는 팀)  \
# 1  □ 위치 : 북구 저불로 73번길 22-3(용봉동)\n□ 지원공간\n❍ 사무실 겸 ...           null
# 2  군청 및 사업소, 읍․면 행정복지센터에서 직무경험을 할 수 있도록 하고, 1일 78...            24명
# 3  □ 대출한도 : 업체당 최대 50백만원 이내\n□ 보증기간 : 1년 / 5년\n□ ...          200억원
# 4  □ 면접용 정장 무료 대여\n❍ 대여항목 : 재킷, 셔츠, 바지, 넥타이 블라우스,...              -
# 5  □ 청년구직자 면접 정장 무료 대여(1인당 연간 5회 한도 / 대여기간 최대 3박 ...           null
# 6  (청년카페운영) 일상 및 구직의욕 유지를 지원하기 위한 맞춤형 프로그램 - (직장적...              -
# 7                               경제활동 기회 제공 및 생계지원 사업    37명(14개 사업)
# 8          취업절차 : 지원서제출 ⇒ 지원서관리 ⇒ 기업연계 ⇒ 민간일자리 직접 연계           null
# 9                                   청년 소상공인을 위한 심리교육              -
#
#                   bizPrdCn prdRpttSecd  ...
# 0                     null      002004  ...  \
# 1                     null      002001  ...
# 2                        -      002004  ...
# 3                     null      002004  ...
# 4  2024.01.01.~2024.12.31.      002004  ...
# 5                     null      002001  ...
# 6                        -      002001  ...
# 7    2024. 8. 1. ~ 12. 20.      002004  ...
# 8                     null      002001  ...
# 9                     null      002004  ...
#
#                                         rfcSiteUrla1            rfcSiteUrla2
# 0                                               null                    null  \
# 1                            https://www.iplexgj.com  https://www.gjtp.or.kr
# 2                                                  -                       -
# 3  https://www.gjsinbo.or.kr/?d=guarantee_product...                    null
# 4                                                  -                       -
# 5                                               null                    null
# 6  https://www.daejeonyouthportal.kr/content/CT_0...                       -
# 7  https://www.ddm.go.kr/www/selectBbsNttView.do?...                    null
# 8  https://www.junggu.seoul.kr/content.do?cmsid=1...                    null
# 9                                               null                    null
#
#            mngtMson mngtMrofCherCn    cherCtpcCn
# 0        북구 청년미래정책관           null          null  \
# 1       광주광역시 창업진흥과           null          null
# 2               순창군              -  063-650-1236
# 3       광주광역시 창업진흥과           null          null
# 4  광주광역시 남구청 일자리정책과              -             -
# 5       광주광역시 청년정책관           null  062-613-2174
# 6                 -              -             -
# 7       동대문구 일자리청년과           null  02-2127-4973
# 8            서울시 중구         일자리경제과  02-3396-5682
# 9           서울시 중구청           null          null
#
#                                             cnsgNmor tintCherCn
# 0                                             북구청년센터       null  \
# 1                                         (재)광주테크노파크       null
# 2                                                순창군          -
# 3                                           광주신용보증재단       null
# 4                                                  -          -
# 5                                  토닥토닥 청년일자리(JOB)카페       null
# 6  대전일자리지원센터(☏ 042-719-8335), 대전청년내일센터(☏ 070-7778...          -
# 7                                            주관기관 동일       null
# 8                                            주관기관 동일       null
# 9                                       행복잇다 사회적협동조합       null
#
#    tintCherCtpcCn                                               etct polyRlmCd
# 0            null  □ 문의처\n❍ 북구청년센터 T.410-8262~3 / 카카오톡 채널 @광주북구청년...    023010
# 1            null  □ 문의처\n❍ (재)광주테크노파크 기업지원단 I-PLEX센터(전담기관) T. 06...    023010
# 2    063-650-1236                                                  -    023010
# 3            null   문의처\n- 광주신용보증재단(062-950-0000, www.gjsinbo.or.kr)    023010
# 4               -                     문의처 : 남구청 일자리정책과(062-607-2681)    023010
# 5  062-372-5990~3  문의처\n❍ 카카오톡 플러스친구 : 토닥토닥청년일자리카페\n❍ 토닥토닥 청년일자리(...    023010
# 6               -                                                  -    023010
# 7            null  동대문구 일자리청년과 ☎02-2127-4973(동행일자리사업)   \n\n- 기타 ...    023010
# 8            null                                               null    023010
# 9            null                                               null    023030
#
# [10 rows x 33 columns]
# 데이터가 youth_policy_data.csv 파일로 저장되었습니다.

# %% [markdown]
# # Fail Code (1)

# %%
# pip install requests

# # [notice] A new release of pip available: 22.3.1 -> 24.1.1
# #[notice] To update, run: python.exe -m pip install --upgrade pip
# Out:
# Requirement already satisfied: requests in c:\users\pc\appdata\local\programs\python\python311\lib\site-packages (2.31.0)Note: you may need to restart the kernel to use updated packages.
#
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\pc\appdata\local\programs\python\python311\lib\site-packages (from requests) (3.1.0)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\pc\appdata\local\programs\python\python311\lib\site-packages (from requests) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\pc\appdata\local\programs\python\python311\lib\site-packages (from requests) (1.26.15)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\pc\appdata\local\programs\python\python311\lib\site-packages (from requests) (2022.12.7)
# [notice] A new release of pip available: 22.3.1 -> 24.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# import requests
# import xml.etree.ElementTree as ET

# # API 키 (예제용으로 주어진 키)
# api_key = "fed94136a305f851b96569cf"

# # API 요청 URL
# url = "https://www.youthcenter.go.kr/opi/youthPlcyList.do"

# %%
# # 쿼리 파라미터 설정 (예시)
# params = {
#     "openApiVlak": api_key,
#     "pageIndex": 1,
#     "display": 10,
#     "query": "청년취업",
#     "bizTycdSel": "023010,023020",
#     "srchPolyBizSecd": "003002001,003002002",
#     "keyword": "채용,구직,기관"
# }

# %%
# # API 요청 보내기
# response = requests.get(url, params=params)

# %%
# # 응답 상태 코드 확인
# if response.status_code == 200:
#     try:
#         # 응답 텍스트를 먼저 출력하여 확인
#         print("응답 텍스트 확인:")
#         print(response.text)
        
#         # XML 응답 데이터를 파싱
#         root = ET.fromstring(response.content)
        
#         # 루트 요소 확인
#         print(f"루트 요소: {root.tag}")
        
#         # XML 데이터 구조 확인 및 출력
#         print("XML 데이터 구조 확인:")
#         for youthPolicy in root.findall('youthPolicy'):
#             print("정책 ID:", youthPolicy.find('bizId').text)
#             print("정책명:", youthPolicy.find('polyBizSjnm').text)
#             print("정책소개:", youthPolicy.find('polyItcnCn').text)
#             print("지원내용:", youthPolicy.find('sporCn').text)
#             print("지원대상:", youthPolicy.find('trgetDtl').text if youthPolicy.find('trgetDtl') is not None else "N/A")
#             print("지원기간:", youthPolicy.find('bizPrdCn').text)
#             print("신청기간:", youthPolicy.find('rqutPrdCn').text)
#             print("-" * 40)
#     except ET.ParseError as e:
#         print("XML 파싱 오류가 발생했습니다:", e)
# else:
#     print(f"데이터를 가져오지 못했습니다. 상태 코드: {response.status_code}")
# Out:
# 응답 텍스트 확인:
# <?xml version="1.0" encoding="UTF-8"?>
# <youthPolicyList>
#    <pageIndex>0</pageIndex>
#    <totalCnt>0</totalCnt>
# </youthPolicyList>
#
# 루트 요소: youthPolicyList
# XML 데이터 구조 확인:

# %%
# # 응답 상태 코드 확인
# if response.status_code == 200:
#     try:
#         # XML 응답 데이터를 파싱
#         root = ET.fromstring(response.content)
        
#         # XML 데이터 구조 확인 및 출력
#         print("<?xml version=\"1.0\" encoding=\"UTF-8\"?>")
#         print("<youthPolicyList>")
#         print(f"   <pageIndex>{root.find('pageIndex').text}</pageIndex>")
#         print(f"   <totalCnt>{root.find('totalCnt').text}</totalCnt>")
        
#         for youthPolicy in root.findall('youthPolicy'):
#             print("   <youthPolicy>")
#             print(f"      <rnum>{youthPolicy.find('rnum').text}</rnum>")
#             print(f"      <bizId><![CDATA[{youthPolicy.find('bizId').text}]]></bizId>")
#             print(f"      <polyBizSecd>{youthPolicy.find('polyBizSecd').text}</polyBizSecd>")
#             print(f"      <polyBizTy>{youthPolicy.find('polyBizTy').text}</polyBizTy>")
#             print(f"      <polyBizSjnm><![CDATA[{youthPolicy.find('polyBizSjnm').text}]]></polyBizSjnm>")
#             print(f"      <polyItcnCn><![CDATA[{youthPolicy.find('polyItcnCn').text}]]></polyItcnCn>")
#             print(f"      <sporCn><![CDATA[{youthPolicy.find('sporCn').text}]]></sporCn>")
#             print(f"      <sporScvl><![CDATA[{youthPolicy.find('sporScvl').text}]]></sporScvl>")
#             print(f"      <bizPrdCn><![CDATA[{youthPolicy.find('bizPrdCn').text}]]></bizPrdCn>")
#             print(f"      <prdRpttSecd><![CDATA[{youthPolicy.find('prdRpttSecd').text}]]></prdRpttSecd>")
#             print(f"      <rqutPrdCn><![CDATA[{youthPolicy.find('rqutPrdCn').text}]]></rqutPrdCn>")
#             print(f"      <ageInfo><![CDATA[{youthPolicy.find('ageInfo').text}]]></ageInfo>")
#             print(f"      <majrRqisCn><![CDATA[{youthPolicy.find('majrRqisCn').text}]]></majrRqisCn>")
#             print(f"      <empmSttsCn><![CDATA[{youthPolicy.find('empmSttsCn').text}]]></empmSttsCn>")
#             print(f"      <splzRlmRqisCn><![CDATA[{youthPolicy.find('splzRlmRqisCn').text}]]></splzRlmRqisCn>")
#             print(f"      <accrRqisCn><![CDATA[{youthPolicy.find('accrRqisCn').text}]]></accrRqisCn>")
#             print(f"      <prcpCn><![CDATA[{youthPolicy.find('prcpCn').text}]]></prcpCn>")
#             print(f"      <aditRscn><![CDATA[{youthPolicy.find('aditRscn').text if youthPolicy.find('aditRscn') is not None else 'null'}]]></aditRscn>")
#             print(f"      <prcpLmttTrgtCn><![CDATA[{youthPolicy.find('prcpLmttTrgtCn').text if youthPolicy.find('prcpLmttTrgtCn') is not None else 'null'}]]></prcpLmttTrgtCn>")
#             print(f"      <rqutProcCn><![CDATA[{youthPolicy.find('rqutProcCn').text}]]></rqutProcCn>")
#             print(f"      <pstnPaprCn><![CDATA[{youthPolicy.find('pstnPaprCn').text if youthPolicy.find('pstnPaprCn') is not None else 'null'}]]></pstnPaprCn>")
#             print(f"      <jdgnPresCn><![CDATA[{youthPolicy.find('jdgnPresCn').text}]]></jdgnPresCn>")
#             print(f"      <rqutUrla><![CDATA[{youthPolicy.find('rqutUrla').text if youthPolicy.find('rqutUrla') is not None else 'null'}]]></rqutUrla>")
#             print(f"      <rfcSiteUrla1><![CDATA[{youthPolicy.find('rfcSiteUrla1').text}]]></rfcSiteUrla1>")
#             print(f"      <rfcSiteUrla2><![CDATA[{youthPolicy.find('rfcSiteUrla2').text if youthPolicy.find('rfcSiteUrla2') is not None else 'null'}]]></rfcSiteUrla2>")
#             print(f"      <mngtMson><![CDATA[{youthPolicy.find('mngtMson').text}]]></mngtMson>")
#             print(f"      <mngtMrofCherCn><![CDATA[{youthPolicy.find('mngtMrofCherCn').text if youthPolicy.find('mngtMrofCherCn') is not None else 'null'}]]></mngtMrofCherCn>")
#             print(f"      <cherCtpcCn><![CDATA[{youthPolicy.find('cherCtpcCn').text}]]></cherCtpcCn>")
#             print(f"      <cnsgNmor><![CDATA[{youthPolicy.find('cnsgNmor').text}]]></cnsgNmor>")
#             print(f"      <tintCherCn><![CDATA[{youthPolicy.find('tintCherCn').text if youthPolicy.find('tintCherCn') is not None else 'null'}]]></tintCherCn>")
#             print(f"      <tintCherCtpcCn><![CDATA[{youthPolicy.find('tintCherCtpcCn').text if youthPolicy.find('tintCherCtpcCn') is not None else 'null'}]]></tintCherCtpcCn>")
#             print(f"      <etct><![CDATA[{youthPolicy.find('etct').text}]]></etct>")
#             print(f"      <polyRlmCd><![CDATA[{youthPolicy.find('polyRlmCd').text}]]></polyRlmCd>")
#             print("   </youthPolicy>")
        
#         print("</youthPolicyList>")
        
#     except ET.ParseError as e:
#         print("XML 파싱 오류가 발생했습니다:", e)
# else:
#     print(f"데이터를 가져오지 못했습니다. 상태 코드: {response.status_code}")
# Out:
# <?xml version="1.0" encoding="UTF-8"?>
# <youthPolicyList>
#    <pageIndex>0</pageIndex>
#    <totalCnt>0</totalCnt>
# </youthPolicyList>
